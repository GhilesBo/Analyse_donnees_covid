# %%
import pandas as pd

# %%
df = pd.read_csv("../owid-covid-data.csv")

# %%
df["dated"] = pd.to_datetime(df["date"])
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 160232      ZWE    Africa     Zimbabwe  2022-02-03     230170.0      158.0
# 160233      ZWE    Africa     Zimbabwe  2022-02-04     230170.0        0.0
# 160234      ZWE    Africa     Zimbabwe  2022-02-05     230402.0      232.0
# 160235      ZWE    Africa     Zimbabwe  2022-02-06     230402.0        NaN
# 160236      ZWE    Africa     Zimbabwe  2022-02-07     230402.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 160232             153.429        5357.0         5.0                4.714
# 160233             119.571        5357.0         0.0                3.429
# 160234             141.000        5362.0         5.0                4.143
# 160235                 NaN        5362.0         0.0                3.571
# 160236                 NaN        5362.0         0.0                3.429
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 160232  ...          30.7                  36.791                         1.7
# 160233  ...          30.7                  36.791                         1.7
# 160234  ...          30.7                  36.791                         1.7
# 160235  ...          30.7                  36.791                         1.7
# 160236  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  \
# 0                 64.83                    0.511
# 1                 64.83                    0.511
# 2                 64.83                    0.511
# 3                 64.83                    0.511
# 4                 64.83                    0.511
# ...                 ...                      ...
# 160232            61.49                    0.571
# 160233            61.49                    0.571
# 160234            61.49                    0.571
# 160235            61.49                    0.571
# 160236            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 160232                                   NaN                          NaN
# 160233                                   NaN                          NaN
# 160234                                   NaN                          NaN
# 160235                                   NaN                          NaN
# 160236                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million      dated
# 0                    NaN                                      NaN 2020-02-24
# 1                    NaN                                      NaN 2020-02-25
# 2                    NaN                                      NaN 2020-02-26
# 3                    NaN                                      NaN 2020-02-27
# 4                    NaN                                      NaN 2020-02-28
# ...                  ...                                      ...        ...
# 160232               NaN                                      NaN 2022-02-03
# 160233               NaN                                      NaN 2022-02-04
# 160234               NaN                                      NaN 2022-02-05
# 160235               NaN                                      NaN 2022-02-06
# 160236               NaN                                      NaN 2022-02-07
#
# [160237 rows x 68 columns]

# %% [markdown]
# Méthode pour choisir un pays

# %%
filtre_pays = df["location"] == "France"

# %%
df_filtre = df[filtre_pays]

# %%
df_filtre.tail(10)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 52621      FRA    Europe   France  2022-01-29   18860575.0   332398.0
# 52622      FRA    Europe   France  2022-01-30   19110023.0   249448.0
# 52623      FRA    Europe   France  2022-01-31   19196399.0    86376.0
# 52624      FRA    Europe   France  2022-02-01   19609576.0   413177.0
# 52625      FRA    Europe   France  2022-02-02   19924939.0   315363.0
# 52626      FRA    Europe   France  2022-02-03   20199291.0   274352.0
# 52627      FRA    Europe   France  2022-02-04   20440340.0   241049.0
# 52628      FRA    Europe   France  2022-02-05   20654882.0   214542.0
# 52629      FRA    Europe   France  2022-02-06   20810321.0   155439.0
# 52630      FRA    Europe   France  2022-02-07   20856322.0    46001.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 52621          345465.143      130523.0       178.0              277.571  ...
# 52622          338012.857      130650.0       127.0              279.286  ...
# 52623          334855.000      131011.0       361.0              274.714  ...
# 52624          322093.571      131379.0       368.0              260.286  ...
# 52625          306126.000      131655.0       276.0              263.143  ...
# 52626          289231.000      131919.0       264.0              262.429  ...
# 52627          273166.143      132274.0       355.0              275.571  ...
# 52628          256329.571      132444.0       170.0              274.429  ...
# 52629          242899.714      132573.0       129.0              274.714  ...
# 52630          237131.857      132990.0       417.0              282.714  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 52621          35.6                     NaN                        5.98
# 52622          35.6                     NaN                        5.98
# 52623          35.6                     NaN                        5.98
# 52624          35.6                     NaN                        5.98
# 52625          35.6                     NaN                        5.98
# 52626          35.6                     NaN                        5.98
# 52627          35.6                     NaN                        5.98
# 52628          35.6                     NaN                        5.98
# 52629          35.6                     NaN                        5.98
# 52630          35.6                     NaN                        5.98
#
#        life_expectancy  human_development_index  \
# 52621            82.66                    0.901
# 52622            82.66                    0.901
# 52623            82.66                    0.901
# 52624            82.66                    0.901
# 52625            82.66                    0.901
# 52626            82.66                    0.901
# 52627            82.66                    0.901
# 52628            82.66                    0.901
# 52629            82.66                    0.901
# 52630            82.66                    0.901
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 52621                                   NaN                          NaN
# 52622                                   NaN                          NaN
# 52623                                   NaN                          NaN
# 52624                                   NaN                          NaN
# 52625                                   NaN                          NaN
# 52626                                   NaN                          NaN
# 52627                                   NaN                          NaN
# 52628                                   NaN                          NaN
# 52629                                   NaN                          NaN
# 52630                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million      dated
# 52621               NaN                                      NaN 2022-01-29
# 52622               NaN                                      NaN 2022-01-30
# 52623               NaN                                      NaN 2022-01-31
# 52624               NaN                                      NaN 2022-02-01
# 52625               NaN                                      NaN 2022-02-02
# 52626               NaN                                      NaN 2022-02-03
# 52627               NaN                                      NaN 2022-02-04
# 52628               NaN                                      NaN 2022-02-05
# 52629               NaN                                      NaN 2022-02-06
# 52630               NaN                                      NaN 2022-02-07
#
# [10 rows x 68 columns]

# %% [markdown]
# fonction -Filter-

# %%
date_voulue = '2022-02-07'

# %%
filtre_date = df_filtre[df_filtre['dated'] >= date_voulue]

# %%
filtre_date
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 52630      FRA    Europe   France  2022-02-07   20856322.0    46001.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 52630          237131.857      132990.0       417.0              282.714  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 52630          35.6                     NaN                        5.98
#
#        life_expectancy  human_development_index  \
# 52630            82.66                    0.901
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 52630                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million      dated
# 52630               NaN                                      NaN 2022-02-07
#
# [1 rows x 68 columns]

# %% [markdown]
# code ci-dessous pour avoir un histogramme de l'avancé du covid par pays

# %% [markdown]
# df_AFG.groupby(df_AFG["date"].dt.floor("h")).sum()["total_cases"].plot()

# %% [markdown]
# ax = df_AFG["total_cases"].plot.hist(stacked = True, bins = 50)
# ax.set_yscale('log')

# %%
df_filtre.groupby(df_filtre["dated"].dt.floor("30D")).sum()["total_cases"].plot()
# Out:
# <AxesSubplot:xlabel='dated'>

# %%
df.dtypes
# Out:
# iso_code                                           object
# continent                                          object
# location                                           object
# date                                               object
# total_cases                                       float64
#                                                 ...
# excess_mortality_cumulative_absolute              float64
# excess_mortality_cumulative                       float64
# excess_mortality                                  float64
# excess_mortality_cumulative_per_million           float64
# dated                                      datetime64[ns]
# Length: 68, dtype: object

# %%
ax = df_filtre["total_cases"].plot.hist(stacked = True, bins = 50)
ax.set_yscale('log')

# %%
from matplotlib import pyplot as plt

# %%
df_filtre.total_cases.value_counts()
# Out:
# 12.0          10
# 6.0            7
# 11.0           7
# 3.0            3
# 5.0            3
#               ..
# 970622.0       1
# 997419.0       1
# 1038232.0      1
# 1080445.0      1
# 20856322.0     1
# Name: total_cases, Length: 719, dtype: int64

# %%
multi_index = df.set_index(['continent' , 'location'])

# %%
country_sum = multi_index.groupby(['location']).agg({'total_cases':['sum'], 'total_deaths':['sum'] })

# %%
country_sum.columns = ['nb_cas_total' , 'nb_total_morts']

# %%
country_sum
# Out:
#                    nb_cas_total  nb_total_morts
# location
# Afghanistan        5.411511e+07    2.356234e+06
# Africa             2.914666e+09    7.297631e+07
# Albania            6.388852e+07    1.084667e+06
# Algeria            7.669248e+07    2.187060e+06
# Andorra            6.954421e+06    6.557600e+04
# ...                         ...             ...
# Wallis and Futuna  1.485150e+05    2.156000e+03
# World              8.773863e+10    1.853344e+09
# Yemen              3.187439e+06    6.657740e+05
# Zambia             6.616951e+07    1.049708e+06
# Zimbabwe           3.997753e+07    1.265535e+06
#
# [238 rows x 2 columns]

# %% [markdown]
# tri de nb_cas_total et nb_total_morts

# %%
sorted_df_cases = country_sum.sort_values(['nb_cas_total'], ascending=False)
sorted_df_deaths = country_sum.sort_values(['nb_total_morts'], ascending=False)

# %%
sorted_df_cases.head(10)
# Out:
#                      nb_cas_total  nb_total_morts
# location
# World                8.773863e+10    1.853344e+09
# High income          4.014909e+10    7.338938e+08
# Upper middle income  2.688002e+10    7.492430e+08
# Asia                 2.533691e+10    3.765762e+08
# Europe               2.457648e+10    5.188355e+08
# North America        2.071290e+10    4.492330e+08
# Lower middle income  2.024993e+10    3.584601e+08
# United States        1.756325e+10    3.041886e+08
# European Union       1.608536e+10    3.340248e+08
# South America        1.405814e+10    4.346180e+08

# %%
sort_filtered_cases = sorted_df_cases.drop(['World', 'Upper middle income', 'High income', 'Europe', 'North America', 'South America', 'Asia', 'Lower middle income', 'European Union'])

# %%
sort_filtered_deaths = sorted_df_deaths.drop(['World', 'Upper middle income', 'High income', 'Europe', 'North America', 'South America', 'Asia', 'Lower middle income', 'European Union'])

# %%
sort_filtered_cases.head(10)
# Out:
#                 nb_cas_total  nb_total_morts
# location
# United States   1.756325e+10     304188594.0
# India           1.176168e+10     157166009.0
# Brazil          8.009474e+09     220386987.0
# United Kingdom  3.005982e+09      64072464.0
# Russia          2.932821e+09      73147825.0
# France          2.929957e+09      52482909.0
# Africa          2.914666e+09      72976311.0
# Turkey          2.534380e+09      23477757.0
# Spain           1.993198e+09      40847281.0
# Italy           1.989809e+09      59600455.0

# %%
sort_filtered_deaths.head(10)
# Out:
#                 nb_cas_total  nb_total_morts
# location
# United States   1.756325e+10     304188594.0
# Brazil          8.009474e+09     220386987.0
# India           1.176168e+10     157166009.0
# Mexico          1.349158e+09     111778913.0
# Peru            9.315684e+08      85752463.0
# Russia          2.932821e+09      73147825.0
# Africa          2.914666e+09      72976311.0
# United Kingdom  3.005982e+09      64072464.0
# Italy           1.989809e+09      59600455.0
# France          2.929957e+09      52482909.0

# %%
sort_filtered_cases['nb_cas_total'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='nb_cas_total'>

# %%
sort_filtered_deaths['nb_total_morts'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='nb_total_morts'>
